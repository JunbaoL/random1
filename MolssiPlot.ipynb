# %%
ls data
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
import os.path

ethanol_file = os.path.join('data', 'outfiles', 'ethanol.out')
print(ethanol_file)
# Out:
# data/outfiles/ethanol.out

# %%
outfile = open(ethanol_file, "r")
data = outfile.readlines()

# %%
outfile.close()

# %%
with open(ethanol_file, "r") as outfile:
    data = outfile.readlines()

# %%
print(len(data))
# Out:
# 270

# %%
ls data
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
cd outfiles/
# Out:
# [Errno 2] No such file or directory: 'outfiles/'
# /Users/junbao/Desktop/cms-workshop

# %%
for line in data:
    print(line)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.1 release
#
#
#
#                          Git: Rev {HEAD} add49b9
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. in press (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#     -----------------------------------------------------------------------
#
#
#
#
#
#     Psi4 started on: Tuesday, 27 June 2017 12:10PM
#
#
#
#     Process ID:  10591
#
# ...

# %%
for element in data:
    print(element)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.1 release
#
#
#
#                          Git: Rev {HEAD} add49b9
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. in press (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#     -----------------------------------------------------------------------
#
#
#
#
#
#     Psi4 started on: Tuesday, 27 June 2017 12:10PM
#
#
#
#     Process ID:  10591
#
# ...

# %%
for line in data:
    if 'Final Energy' in line:
        energy_line = line
        print(energy_line)
# Out:
#   @DF-RHF Final Energy:  -154.09130176573018

# %%
energy_line.split()
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy_line.split(' ')
# Out:
# ['', '', '@DF-RHF', 'Final', 'Energy:', '', '-154.09130176573018\n']

# %%
word = energy_line.split()
print(word)
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy = word[-1]
print(energy)
# Out:
# -154.09130176573018

# %%
float(energy) + 50
# Out:
# -104.09130176573018

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/

# %%
ls data
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
with open('sapt.out', "r") as outfile:
    prac = outfile.readlines()
print(prac)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/1990583982.py in <module>
# ----> 1 with open('sapt.out', "r") as outfile:
#       2     prac = outfile.readlines()
#       3 print(prac)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sapt.out'

# %%
with open('SAPT.out','r') as saptout:
# Out:
#   File "/var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/2325494505.py", line 1
#     with open('SAPT.out','r') as saptout:
#                                          ^
# IndentationError: expected an indented block

# %%
with open('SAPT.out', "r") as outfile:
    prac = outfile.readlines()
print(prac)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/1318971523.py in <module>
# ----> 1 with open('SAPT.out', "r") as outfile:
#       2     prac = outfile.readlines()
#       3 print(prac)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'SAPT.out'

# %%
ls data
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/141306254.py in <module>
# ----> 1 N
#
# NameError: name 'N' is not defined

# %%
ls data
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
with open('sapt.out', 'r') as outfile:
    prac = outfile.readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/2244377309.py in <module>
# ----> 1 with open('sapt.out', 'r') as outfile:
#       2     prac = outfile.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sapt.out'

# %%
important_lines = []
energies = []

with open('sapt.out','r') as saptout:
    for line in saptout:
        if 'Electrostatics    ' in line:
            electro_line = line
            important_lines.append(electro_line)
        if 'Exchange       ' in line:
            exchange_line = line
            important_lines.append(exchange_line)
        if 'Induction      ' in line:
            induction_line = line
            important_lines.append(induction_line)
        if 'Dispersion     ' in line:
            dispersion_line = line
            important_lines.append(dispersion_line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/576303125.py in <module>
#       2 energies = []
#       3
# ----> 4 with open('sapt.out','r') as saptout:
#       5     for line in saptout:
#       6         if 'Electrostatics    ' in line:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sapt.out'

# %%
with open('sapt.out', "r") as outfile:
    prac = outfile.readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/429309632.py in <module>
# ----> 1 with open('sapt.out', "r") as outfile:
#       2     prac = outfile.readline()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sapt.out'

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
cd data
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
cd ../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/

# %%
cd data
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
ls
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
with open('sapt.out', 'r') as outfile:
    prac = outfile.readlines()

# %%
print(prac)
# Out:
# ['\n', '    -----------------------------------------------------------------------\n', '          Psi4: An Open-Source Ab Initio Electronic Structure Package\n', '                               Psi4 1.2.1 release\n', '\n', '                         Git: Rev {HEAD} 406f4de \n', '\n', '\n', '    R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,\n', '    A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,\n', '    R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,\n', '    H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,\n', '    P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,\n', '    F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,\n', '    J. Chem. Theory Comput. 13(7) pp 3185--3197 (2017).\n', '    (doi: 10.1021/acs.jctc.7b00174)\n', '\n', '\n', '                         Additional Contributions by\n', '    P. Kraus, H. Kruse, M. H. Lechner, M. C. Schieber, and R. A. Shaw\n', '\n', '    ----
# ...

# %%
for line in prac:
    print(line)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.2.1 release
#
#
#
#                          Git: Rev {HEAD} 406f4de
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. 13(7) pp 3185--3197 (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#
#
#                          Additional Contributions by
#
#     P. Kraus, H. Kruse, M. H. Lechner, M. C. Schieber, and R. A. Shaw
#
#
#
# ...

# %%
important_line = []
energy = []
for line in prac:
    if 'Electrostatics' in prac:
        energy = line
        important_line.append(energy)
        print(energy)
    if 'Exchange' in line:
        energy = line
        important_line.append(energy)
        print(energy)
    if 'Induction' in line:
        energy = line
        important_line.append(energy)
        print(energy)
    if 'Dispersion' in line:
        energy = line
        important_line.append(energy)
        print(energy)
# Out:
#     Exchange                        3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]
#
#     Induction                      -0.83137115 [mEh]      -0.52169330 [kcal/mol]      -2.18276496 [kJ/mol]
#
#     Dispersion                     -1.50542374 [mEh]      -0.94466770 [kcal/mol]      -3.95249003 [kJ/mol]
#
#     Exchange sSAPT0                 3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]
#
#     Induction sSAPT0               -0.82185559 [mEh]      -0.51572219 [kcal/mol]      -2.15778186 [kJ/mol]
#
#     Dispersion sSAPT0              -1.50279823 [mEh]      -0.94302016 [kcal/mol]      -3.94559675 [kJ/mol]

# %%
print(important_line)
# Out:
# ['    Exchange                        3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]\n', '    Induction                      -0.83137115 [mEh]      -0.52169330 [kcal/mol]      -2.18276496 [kJ/mol]\n', '    Dispersion                     -1.50542374 [mEh]      -0.94466770 [kcal/mol]      -3.95249003 [kJ/mol]\n', '    Exchange sSAPT0                 3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]\n', '    Induction sSAPT0               -0.82185559 [mEh]      -0.51572219 [kcal/mol]      -2.15778186 [kJ/mol]\n', '    Dispersion sSAPT0              -1.50279823 [mEh]      -0.94302016 [kcal/mol]      -3.94559675 [kJ/mol]\n']

# %%
for line in important_line:
    print(important_line)
# Out:
# ['    Exchange                        3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]\n', '    Induction                      -0.83137115 [mEh]      -0.52169330 [kcal/mol]      -2.18276496 [kJ/mol]\n', '    Dispersion                     -1.50542374 [mEh]      -0.94466770 [kcal/mol]      -3.95249003 [kJ/mol]\n', '    Exchange sSAPT0                 3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]\n', '    Induction sSAPT0               -0.82185559 [mEh]      -0.51572219 [kcal/mol]      -2.15778186 [kJ/mol]\n', '    Dispersion sSAPT0              -1.50279823 [mEh]      -0.94302016 [kcal/mol]      -3.94559675 [kJ/mol]\n']
# ...

# %%
important_lines = []
energies = []

with open('sapt.out','r') as saptout:
    for line in saptout:
        if 'Electrostatics    ' in line:
            electro_line = line
            important_lines.append(electro_line)
        if 'Exchange       ' in line:
            exchange_line = line
            important_lines.append(exchange_line)
        if 'Induction      ' in line:
            induction_line = line
            important_lines.append(induction_line)
        if 'Dispersion     ' in line:
            dispersion_line = line
            important_lines.append(dispersion_line)

#print(important_lines)

for line in important_lines:
    words = line.split()
    print(words)
    energy_type = words[0]
    energy_kcal = float(words[3])
    energies.append(energy_kcal)
    print('{} : {} kcal/mol'.format(energy_type, energy_kcal))

total_energy = sum(energies)
print('Total Energy : {} kcal/mol'.format(total_energy))
# Out:
# ['Electrostatics', '-3.59915058', '[mEh]', '-2.25850118', '[kcal/mol]', '-9.44956984', '[kJ/mol]']
# Electrostatics : -2.25850118 kcal/mol
# ['Exchange', '3.62911156', '[mEh]', '2.27730198', '[kcal/mol]', '9.52823241', '[kJ/mol]']
# Exchange : 2.27730198 kcal/mol
# ['Induction', '-0.83137115', '[mEh]', '-0.52169330', '[kcal/mol]', '-2.18276496', '[kJ/mol]']
# Induction : -0.5216933 kcal/mol
# ['Dispersion', '-1.50542374', '[mEh]', '-0.94466770', '[kcal/mol]', '-3.95249003', '[kJ/mol]']
# Dispersion : -0.9446677 kcal/mol
# Total Energy : -1.4475602000000003 kcal/mol

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop/data'

# %%
ls
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
with open('sapt.out','r') as outfile:
    sapt =outfile.readlines()

# %%
print(len(sapt))
# Out:
# 1535

# %%
important_lines = []
for element in sapt:
    if 'Electrostatics' in element and 'sSAPT0' not in element:
        important_lines.append(element)
    if 'Exchange' in element and 'sSAPT0' not in element:
        important_lines.append(element)
    if 'Induction' in element and 'sSAPT0' not in element:
        important_lines.append(element)
    if 'Dispersion' in element and 'sSAPT0' not in element:
        important_lines.append(element)
for line in important_lines:
    print(line)
# Out:
#     Electrostatics                 -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]
#
#     Exchange                        3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]
#
#     Induction                      -0.83137115 [mEh]      -0.52169330 [kcal/mol]      -2.18276496 [kJ/mol]
#
#     Dispersion                     -1.50542374 [mEh]      -0.94466770 [kcal/mol]      -3.95249003 [kJ/mol]

# %%
energy = []
energy_electrostatics=important_lines[0]
print(energy_electrostatics)
# Out:
#     Electrostatics                 -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]

# %%
word = energy_electrostatics.split()

# %%
print(word)
# Out:
# ['Electrostatics', '-3.59915058', '[mEh]', '-2.25850118', '[kcal/mol]', '-9.44956984', '[kJ/mol]']

# %%
energy.append(word[-2])

# %%
print(energy)
# Out:
# ['-9.44956984', -9.44956984, '-9.44956984', '-9.44956984', '9.52823241', '9.52823241']

# %%
energy_exchange = important_lines[1]
word = energy_exchange.split()
energy.append(word[-2])
print(energy)
# Out:
# ['-9.44956984', -9.44956984, '-9.44956984', '-9.44956984', '9.52823241', '9.52823241']

# %%
for line in important_lines:
    words = line.split()
    energy_type = word[0]
    energy_kcal =float(word[-2]) 
    energy.append(energy_kcal)
    print(energy_type, ':', energy_kcal)
    
total_energy = sum(energy)
print('total energy :' , total_energy)
# Out:
# Exchange : 9.52823241
# Exchange : 9.52823241
# Exchange : 9.52823241
# Exchange : 9.52823241
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/1013011248.py in <module>
#       6     print(energy_type, ':', energy_kcal)
#       7
# ----> 8 total_energy = sum(energy)
#       9 print('total energy :' , total_energy)
#      10
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
for line in important_lines:
    words = line.split()
    energy_type = word[0]
    energy_kcal =float(word[3]) 
    energy.append(energy_kcal)
    print(energy_type, ':', energy_kcal)
    
total_energy = sum(energy)
print('total energy :' , total_energy)
# Out:
# Exchange : 2.27730198
# Exchange : 2.27730198
# Exchange : 2.27730198
# Exchange : 2.27730198
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/3894205158.py in <module>
#       6     print(energy_type, ':', energy_kcal)
#       7
# ----> 8 total_energy = sum(energy)
#       9 print('total energy :' , total_energy)
#      10
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop/data'

# %%
ls
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
important_lines = []
energy = []
with open('sapt.out','r') as out:
    saptout = out.readlines()
    for line in saptout:
        if 'Electrostatics' in line and 'sSAPT0' not in line:
            important_lines.append(line)
        if 'Induction' in line and 'sSAPT0' not in line:
            important_lines.append(line)
        if 'Exchange' in line and 'sSAPT0' not in line:
            important_lines.append(line)
        if 'Dispersion' in line and 'sSAPT0' not in line:
            important_lines.append(line)
    for line in important_lines:
        print(line)
    for line in important_lines:
        word = line.split()
        title = word[0]
        energy_kj = word[-2]
        energy.append(float(word[-2]))
        print(title, ':', energy_kj, 'KJ')
    total= sum(energy)
    print(energy)
    print('total', ':', total, 'KJ')
# Out:
#     Electrostatics                 -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]
#
#     Exchange                        3.62911156 [mEh]       2.27730198 [kcal/mol]       9.52823241 [kJ/mol]
#
#     Induction                      -0.83137115 [mEh]      -0.52169330 [kcal/mol]      -2.18276496 [kJ/mol]
#
#     Dispersion                     -1.50542374 [mEh]      -0.94466770 [kcal/mol]      -3.95249003 [kJ/mol]
#
# Electrostatics : -9.44956984 KJ
# Exchange : 9.52823241 KJ
# Induction : -2.18276496 KJ
# Dispersion : -3.95249003 KJ
# [-9.44956984, 9.52823241, -2.18276496, -3.95249003]
# total : -6.056592420000001 KJ

# %%
for linenum, line in enumerate(data):
    if 'Center' in line:
        print(linenum)
        print(line)
# Out:
# 77
#        Center              X                  Y                   Z               Mass

# %%
ls
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
print(data[77])
# Out:
#        Center              X                  Y                   Z               Mass

# %%
print(data[77])
print(data[78])
print(data[79])
print(data[80])
print(data[81])
# Out:
#        Center              X                  Y                   Z               Mass
#
#     ------------   -----------------  -----------------  -----------------  -----------------
#
#            H          0.278612764252     1.265047047666    -1.274211449480     1.007825032070
#
#            C          0.253854764252     1.255132047666    -0.179502449480    12.000000000000
#
#            H          1.294208764252     1.265046047666     0.162059550520     1.007825032070

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop/data'

# %%
cd ../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/

# %%
cd data/
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
ls
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
cd outfiles/
# Out:
# /Users/junbao/Desktop/cms-workshop/data/outfiles

# %%
ls
# Out:
# butanol.out   ethanol.out   hexanol.out   nonanol.out   pentanol.out
# decanol.out   heptanol.out  methanol.out  octanol.out   propanol.out

# %%
import os
output = os.path()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/1270781001.py in <module>
#       1 import os
# ----> 2 output = os.path()
#
# TypeError: 'module' object is not callable

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop/data/outfiles'

# %%
cd ../../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
cd data/
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop/data'

# %%
ls
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
cd outfiles/
# Out:
# /Users/junbao/Desktop/cms-workshop/data/outfiles

# %%
ls
# Out:
# butanol.out   ethanol.out   hexanol.out   nonanol.out   pentanol.out
# decanol.out   heptanol.out  methanol.out  octanol.out   propanol.out

# %%
outfile_directory = os.path.join('data', 'outfiles')

# %%
print(outfile_directory)
# Out:
# data/outfiles

# %%
file_location = os.path.join(outfile_directory, '*.out')

# %%
print(file_location)
# Out:
# data/outfiles/*.out

# %%
import glob
filename = glob.glob(file_location)
print(filename)
# Out:
# []

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop/data/outfiles'

# %%
cd ../../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
import glob
filename = glob.glob(file_location)
print(filename)
# Out:
# ['data/outfiles/propanol.out', 'data/outfiles/pentanol.out', 'data/outfiles/decanol.out', 'data/outfiles/methanol.out', 'data/outfiles/octanol.out', 'data/outfiles/ethanol.out', 'data/outfiles/hexanol.out', 'data/outfiles/heptanol.out', 'data/outfiles/butanol.out', 'data/outfiles/nonanol.out']

# %%
for f in filename:
    outfile = open(f,'r')
    data = outfile.readlines()
    outfile.close()
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            word = energy_line.split()
            energy = float(word[3])
            print(energy)
# Out:
# -193.12836249728798
# -271.20138119895074
# -466.3836241400086
# -115.04800861868374
# -388.3110864554743
# -154.09130176573018
# -310.2385332251633
# -349.27397687072676
# -232.1655798347283
# -427.3465180082815

# %%
first_file = filename[0]
print(first_file)

file_name=os.path.basename(first_file)
print(file_name)
# Out:
# data/outfiles/propanol.out
# propanol.out

# %%
word=first_file.split('.')
print(word)
# Out:
# ['data/outfiles/propanol', 'out']

# %%
print(word[0])
# Out:
# data/outfiles/propanol

# %%
split_filename = file_name.split('.')
molecule_name = split_filename[0]
print(molecule_name)
# Out:
# propanol

# %%
print(file_name)
# Out:
# propanol.out

# %%
print(first_file)
# Out:
# data/outfiles/propanol.out

# %%
word=file_name.split('.')
print(word[0])
# Out:
# propanol

# %%
for f in filename:
    file_name = os.path.basename(f)
    word = file_name.split('.')
    molecule_name = word[0]
    
    outfile = open(f,'r')
    data = outfile.readlines()
    outfile.close()
    
    for line in data:
        if 'Final Energy' in line:
            energy_line = line
            energysplit= energy_line.split()
            energystr=energysplit[3]
            energynum=float(energystr)
            print(molecule_name, energynum)
# Out:
# propanol -193.12836249728798
# pentanol -271.20138119895074
# decanol -466.3836241400086
# methanol -115.04800861868374
# octanol -388.3110864554743
# ethanol -154.09130176573018
# hexanol -310.2385332251633
# heptanol -349.27397687072676
# butanol -232.1655798347283
# nonanol -427.3465180082815

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/

# %%
cd data
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
ls
# Out:
# 03_Prod.mdout              outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz
# distance_data_headers.csv

# %%
#open a file or writing
datafile=open('Etot.txt', 'w+')
#open the file and put it in a list
with open('03_Prod.mdout','r') as fileout:
    word=fileout.readlines()
    #print(word)
    #find the total energy line
    for f in word:
        if 'Etot' in f:
            energy_line=f
            energysplit1=energy_line.split('=')
            energysplit2=energysplit1[1]
            energysplit3=energysplit2.split('E')
            energy=energysplit3[0]
            print(energy)
            datafile.write(F'{energy}\n')

datafile.close()
# Out:
#      -4585.1049
#      -4573.5326
#      -4548.1223
#      -4525.3410
#      -4542.8995
#      -4550.9376
#      -4543.8652
#      -4570.4109
#      -4550.4225
#      -4585.2078
#      -4577.3788
#      -4583.5594
#      -4605.5086
#      -4615.4200
#      -4583.6069
#      -4534.2492
#      -4571.4911
#      -4580.2937
#      -4555.4327
#      -4567.5687
#      -4566.0038
#      -4547.9737
#      -4603.6717
#      -4611.0889
#      -4694.2189
#      -4678.6558
#      -4679.2889
#      -4650.4214
#      -4637.4849
#      -4677.2461
#      -4659.6974
#      -4592.8300
#      -4622.1237
#      -4626.0868
#      -4614.5996
#      -4625.5348
#      -4569.7752
#      -4625.0792
#      -4653.4614
#      -4637.6852
#      -4643.8673
#      -4619.5255
#      -4663.3843
#      -4631.8386
#      -4680.3524
#      -4722.1579
#      -4696.5022
#      -4729.6126
#      -4703.1835
#      -4707.8668
#      -4660.0768
#      -4673.0967
#      -4656.3795
#      -4627.9210
#      -4599.7806
# ...

# %%
ls
# Out:
# 03_Prod.mdout              distance_data_headers.csv
# Etot.txt                   outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz

# %%
with open('Etot.txt','r') as readfile:
    word = readfile.readlines()
    for line in word:
        print(line)
# Out:
#      -4585.1049
#
#      -4573.5326
#
#      -4548.1223
#
#      -4525.3410
#
#      -4542.8995
#
#      -4550.9376
#
#      -4543.8652
#
#      -4570.4109
#
#      -4550.4225
#
#      -4585.2078
#
#      -4577.3788
#
#      -4583.5594
#
#      -4605.5086
#
#      -4615.4200
#
#      -4583.6069
#
#      -4534.2492
#
#      -4571.4911
#
#      -4580.2937
#
#      -4555.4327
#
#      -4567.5687
#
#      -4566.0038
#
#      -4547.9737
#
#      -4603.6717
#
#      -4611.0889
#
#      -4694.2189
#
#      -4678.6558
#
#      -4679.2889
#
#      -4650.4214
#
#      -4637.4849
#
#      -4677.2461
#
#      -4659.6974
#
#      -4592.8300
#
#      -4622.1237
#
#      -4626.0868
#
#      -4614.5996
#
#      -4625.5348
#
#      -4569.7752
#
#      -4625.0792
#
#      -4653.4614
#
#      -4637.6852
#
#      -4643.8673
#
#      -4619.5255
#
#      -4663.3843
#
#      -4631.8386
#
#      -4680.3524
#
#      -4722.1579
#
#      -4696.5022
#
#      -4729.6126
#
#      -4703.1835
#
#      -4707.8668
#
# ...

# %%
ls
# Out:
# 03_Prod.mdout              distance_data_headers.csv
# Etot.txt                   outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz

# %%
cd ../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/

# %%
cd cms-workshop
# Out:
# [Errno 2] No such file or directory: 'cms-workshop'
# /Users/junbao/Desktop/cms-workshop

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/

# %%
cd MOlSSI\
# Out:
# [Errno 2] No such file or directory: 'MOlSSI '
# /Users/junbao/Desktop/cms-workshop

# %%
cd data/
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
import numpy
help(numpy.genfromtxt)
# Out:
# Help on function genfromtxt in module numpy:
#
# genfromtxt(fname, dtype=<class 'float'>, comments='#', delimiter=None, skip_header=0, skip_footer=0, converters=None, missing_values=None, filling_values=None, usecols=None, names=None, excludelist=None, deletechars=" !#$%&'()*+,-./:;<=>?@[\\]^{|}~", replace_space='_', autostrip=False, case_sensitive=True, defaultfmt='f%i', unpack=None, usemask=False, loose=True, invalid_raise=True, max_rows=None, encoding='bytes', *, like=None)
#     Load data from a text file, with missing values handled as specified.
#
#     Each line past the first `skip_header` lines is split at the `delimiter`
#     character, and characters following the `comments` character are discarded.
#
#     Parameters
#     ----------
#     fname : file, str, pathlib.Path, list of str, generator
#         File, filename, list, or generator to read.  If the filename
#         extension is `.gz` or `.bz2`, the file is first decompressed. Note
# ...

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop/data'

# %%
cd ../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
import os
distance_file = os.path.join('data','distance_data_headers.csv')
distance = numpy.genfromtxt(fname=distance_file, delimiter=',',dtype='unicode')
print(distance)
# Out:
# [['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']
#  ['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
headers = distance[0]
print(headers)
# Out:
# ['Frame' 'THR4_ATP' 'THR4_ASP' 'TYR6_ATP' 'TYR6_ASP']

# %%
data = distance[1:]
print(data)
# Out:
# [['1' '8.9542' '5.8024' '11.5478' '9.9557']
#  ['2' '8.6181' '6.0942' '13.9594' '11.6945']
#  ['3' '9.0066' '6.0637' '13.0924' '11.3043']
#  ...
#  ['9998' '8.6625' '7.7306' '9.5469' '10.3063']
#  ['9999' '9.2456' '7.8886' '9.8151' '10.7564']
#  ['10000' '8.8135' '7.917' '9.9517' '10.7848']]

# %%
data = data.astype(float)
print(data)
# Out:
# [[1.00000e+00 8.95420e+00 5.80240e+00 1.15478e+01 9.95570e+00]
#  [2.00000e+00 8.61810e+00 6.09420e+00 1.39594e+01 1.16945e+01]
#  [3.00000e+00 9.00660e+00 6.06370e+00 1.30924e+01 1.13043e+01]
#  ...
#  [9.99800e+03 8.66250e+00 7.73060e+00 9.54690e+00 1.03063e+01]
#  [9.99900e+03 9.24560e+00 7.88860e+00 9.81510e+00 1.07564e+01]
#  [1.00000e+04 8.81350e+00 7.91700e+00 9.95170e+00 1.07848e+01]]

# %%
print(data[0,1])
print(data[1,0])
# Out:
# 8.9542
# 2.0

# %%
small_data = data[0:10,0:3]
print(small_data)
# Out:
# [[ 1.      8.9542  5.8024]
#  [ 2.      8.6181  6.0942]
#  [ 3.      9.0066  6.0637]
#  [ 4.      9.2002  6.0227]
#  [ 5.      9.1294  5.9365]
#  [ 6.      9.0462  6.2553]
#  [ 7.      8.8657  5.9186]
#  [ 8.      9.3256  6.2351]
#  [ 9.      9.4184  6.1993]
#  [10.      9.06    6.0478]]

# %%
print(small_data[5,:])
print(small_data[:,1:])
# Out:
# [6.     9.0462 6.2553]
# [[8.9542 5.8024]
#  [8.6181 6.0942]
#  [9.0066 6.0637]
#  [9.2002 6.0227]
#  [9.1294 5.9365]
#  [9.0462 6.2553]
#  [8.8657 5.9186]
#  [9.3256 6.2351]
#  [9.4184 6.1993]
#  [9.06   6.0478]]

# %%
thr4_atp = data[:,1]
avg_thr4_atp=numpy.mean(thr4_atp)
print(avg_thr4_atp)
# Out:
# 10.876950930000001

# %%
num_columns = len(data[0,:])
print(num_columns)
# Out:
# 5

# %%
for i in range(1,num_columns):
    column=data[:,i]
    avg_col=numpy.mean(column)
    print(F'{headers[i]}:{avg_col}')
# Out:
# THR4_ATP:10.876950930000001
# THR4_ASP:7.342344959999999
# TYR6_ATP:11.209791329999998
# TYR6_ASP:10.9934435

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/

# %%
cd data
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
cd ../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
import numpy
import os
water_file=os.path.join('data','water.xyz')
water=numpy.genfromtxt(fname=water_file, dtype='unicode', skip_header=2)
print(water)
# Out:
# [['O' '0.000000' '-0.007156' '0.965491']
#  ['H1' '-0.000000' '0.001486' '-0.003471']
#  ['H2' '0.000000' '0.931026' '1.207929']]

# %%
datafile=open('bond_length.txt','w+')
symbols=water[:,0]
coordinate=water[:,1:]
coordinate=coordinate.astype(float)
num_atoms = len(symbols)
for num1 in range(0,num_atoms):
    for num2 in range(0,num_atoms):
        if num1<num2:
            
            
            xdistance=coordinate[num1,0]-coordinate[num2,0]
            ydistance=coordinate[num1,1]-coordinate[num2,1]
            zdistance=coordinate[num1,2]-coordinate[num2,2]
        
            bond_length=numpy.sqrt(xdistance**2+ydistance**2+zdistance**2)
            if bond_length > 0 and bond_length <= 1.5:
                print(F'{symbols[num1]}to {symbols[num2]}:{bond_length}')
                datafile.write(F'{symbols[num1]}to {symbols[num2]}:{bond_length}\n')
datafile.close()
# Out:
# Oto H1:0.9690005374652793
# Oto H2:0.9690003348647513

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  bond_length.txt
# Untitled.ipynb         data/

# %%
cd data
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
ls
# Out:
# 03_Prod.mdout              distance_data_headers.csv
# Etot.txt                   outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz

# %%
cd ../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
vi bond_length.txt
# Out:
#   File "/var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/3367257639.py", line 1
#     vi bond_length.txt
#        ^
# SyntaxError: invalid syntax

# %%
with open('bond_length.txt','r') as readfile:
    for line in readfile:
        print(line)
# Out:
# Oto H1:0.9690005374652793
#
# Oto H2:0.9690003348647513

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
import os
import numpy

distance_file = os.path.join('data', 'distance_data_headers.csv')
distances = numpy.genfromtxt(fname=distance_file, delimiter=',', dtype='unicode')
headers = distances[0]
data = distances[1:]
data = data.astype(numpy.float)
# Out:
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/3666336147.py:8: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data = data.astype(numpy.float)

# %%
import matplotlib.pyplot

# %%
matplotlib.pyplot.figure()
matplotlib.pyplot.plot(data[:,1])

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(data[:,1])

# %%
sample = headers[1]
print(sample)
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
fig_1=plt.plot(data[:,1], label=sample)
plt.legend()
plt.savefig(F'{sample}.png', dpi=300)
# Out:
# THR4_ATP

# %%
ls
# Out:
# MOlSSI Workshop.ipynb  Untitled.ipynb         data/
# THR4_ATP.png           bond_length.txt

# %%
plt.figure()
plt.xlabel('Simulation Frame')
plt.ylabel('Distance (angstrom)')
plt.plot(data[:,1], label=headers[1])
plt.plot(data[:,2], label=headers[2])
plt.legend()
plt.savefig(F'two_sample.png', dpi=300)

# %%
plt.savefig(F'two_sample.png', dpi=300)

# %%
data_min=numpy.min(data[:,1:])*0.9
data_max=numpy.max(data[:,1:])*1.1
for col in range(1, len(headers)):
    sample=headers[col]
    plt.figure()
    fig=plt.plot(data[:,col], label=headers[col])
    plt.ylim(data_min,data_max)
    plt.legend()
    plt.xlabel('Simulation Frame')
    plt.ylabel('Distance (angstrom)')
    plt.savefig(F'{sample}.png', dpi=300)

# %%
plt.figure()
plt.plot(data[:,0],data[:,1])

# %%
print(data[:,0])
# Out:
# [1.000e+00 2.000e+00 3.000e+00 ... 9.998e+03 9.999e+03 1.000e+04]

# %%
print(data[0::100,0])
# Out:
# [1.000e+00 1.010e+02 2.010e+02 3.010e+02 4.010e+02 5.010e+02 6.010e+02
#  7.010e+02 8.010e+02 9.010e+02 1.001e+03 1.101e+03 1.201e+03 1.301e+03
#  1.401e+03 1.501e+03 1.601e+03 1.701e+03 1.801e+03 1.901e+03 2.001e+03
#  2.101e+03 2.201e+03 2.301e+03 2.401e+03 2.501e+03 2.601e+03 2.701e+03
#  2.801e+03 2.901e+03 3.001e+03 3.101e+03 3.201e+03 3.301e+03 3.401e+03
#  3.501e+03 3.601e+03 3.701e+03 3.801e+03 3.901e+03 4.001e+03 4.101e+03
#  4.201e+03 4.301e+03 4.401e+03 4.501e+03 4.601e+03 4.701e+03 4.801e+03
#  4.901e+03 5.001e+03 5.101e+03 5.201e+03 5.301e+03 5.401e+03 5.501e+03
#  5.601e+03 5.701e+03 5.801e+03 5.901e+03 6.001e+03 6.101e+03 6.201e+03
#  6.301e+03 6.401e+03 6.501e+03 6.601e+03 6.701e+03 6.801e+03 6.901e+03
#  7.001e+03 7.101e+03 7.201e+03 7.301e+03 7.401e+03 7.501e+03 7.601e+03
#  7.701e+03 7.801e+03 7.901e+03 8.001e+03 8.101e+03 8.201e+03 8.301e+03
#  8.401e+03 8.501e+03 8.601e+03 8.701e+03 8.801e+03 8.901e+03 9.001e+03
# ...

# %%
plt.figure()
plt.plot(data[0::100,0],data[0::100,1], ':ok')

# %%
fig, ax=plt.subplots(len(headers)-1,1)

# %%
ax.shape
# Out:
# (4,)

# %%
fig2, ax2=plt.subplots(2,2)
ax2.shape
# Out:
# (2, 2)

# %%
ax[0].plot(data[0::100,0], data[0::100,col])
fig

# %%
ax2[0,0].plot(data[0::100,0],data[0::100,col])
fig2

# %%
fig, ax=plt.subplots(len(headers)-1,1, figsize=(10,10), sharey=True)
for col in range(1,len(headers)):
    sample = headers[col]
    ax[col-1].plot(data[0::100,0],data[0::100,col],label=sample)
    ax[col-1].set_xlabel('Simulation Frame')
    ax[col-1].set_ylabel('Distance (angstrom)')
    ax[col-1].legend

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
import os
import numpy

file_location = os.path.join('data','water.xyz')
xyz_file=numpy.genfromtxt(fname=file_location, skip_header=2, dtype='unicode')
symbols = xyz_file[:,0]
coordinates=xyz_file[:,1:]
coordinates=coordinates.astype(float)
num_atoms=len(symbols)

# %%
def calculate_distance(atom1_coord, atom2_coord):
    """Calculate the distance between two three-dimensional point."""
    x_distance= atom1_coord[0] - atom2_coord[0]
    y_distance= atom1_coord[1] - atom2_coord[1]
    z_distance= atom1_coord[2] - atom2_coord[2]
    bond_length_12 = numpy.sqrt(x_distance**2 + y_distance**2 + z_distance**2)
    return bond_length_12

# %%
for num1 in range(0,num_atoms):
    for num2 in range(0, num_atoms):
        if num1<num2:
            bond_length_12=calculate_distance(coordinates[num1],coordinate[num2])
            if bond_length_12 > 0 and bond_length_12 <= 1.5:
                print(F'{symbols[num1]} : {symbols[num2]} : {bond_length_12}')
# Out:
# O : H1 : 0.9690005374652793
# O : H2 : 0.9690003348647513

# %%
def bond_check(atom_distance):
    if atom_distance > 0 and atom_distance <= 1.5:
        return True
    else:
        return False

# %%
bond_check(1.4)
# Out:
# True

# %%
def bond_check(atom_distance, min_distance=0, max_distance=1.5):
    if atom_distance > min_distance and atom_distance <max_distance:
        return True
    else:
        return False

# %%
bond_check(1.5,max_distance=1.9)
# Out:
# True

# %%
help(calculate_distance)
# Out:
# Help on function calculate_distance in module __main__:
#
# calculate_distance(atom1_coord, atom2_coord)
#     Calculate the distance between two three-dimensional point.

# %%
def open_xyz(file_name):
    xyz=[]
    #import os
    import numpy
    #file_location=os.path.join('data','{file_name}')
    xyz=numpy.genfromtxt(fname=file_name, skip_header=2, dtype='unicode')
    symbols=xyz[:,0]
    xyz_data=xyz[:,1:]
    xyz_data=xyz_data.astype(float)
    return symbols, xyz_data

# %%
open_xyz(data/water.xyz)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/1018410027.py in <module>
# ----> 1 open_xyz(data/water.xyz)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'xyz'

# %%
cd data/
# Out:
# /Users/junbao/Desktop/cms-workshop/data

# %%
# Out:
# 03_Prod.mdout              distance_data_headers.csv
# Etot.txt                   outfiles/
# benzene.xyz                sapt.out
# buckminsterfullerene.xyz   water.xyz

# %%
# Out:
#   File "/var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/2224086093.py", line 1
#     vi water.xyz
#        ^
# SyntaxError: invalid syntax

# %%
def open_xyz1(filename):
     xyz_file = numpy.genfromtxt(fname=filename, skip_header=2, dtype='unicode')
     symbols = xyz_file[:, 0]
     coord = (xyz_file[:, 1:])
     coord = coord.astype(numpy.float)
     return symbols, coord

# %%
open_xyz1(water.xyz)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/976042381.py in <module>
# ----> 1 open_xyz1(water.xyz)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'xyz'

# %%
import numpy
import os

def calculate_distance(atom1_coord, atom2_coord):
    """
    Calculate the distance between two three-dimensional points.
    """
    x_distance = atom1_coord[0] - atom2_coord[0]
    y_distance = atom1_coord[1] - atom2_coord[1]
    z_distance = atom1_coord[2] - atom2_coord[2]
    bond_length_12 = numpy.sqrt(x_distance ** 2 + y_distance ** 2 + z_distance ** 2)
    return bond_length_12

def bond_check(atom_distance, minimum_length=0, maximum_length=1.5):
    """Check if a distance is a bond based on a minimum and maximum bond length"""

    if atom_distance > minimum_length and atom_distance <= maximum_length:
        return True
    else:
        return False

#def open_xyz(filename):
     """
     Open and read an xyz file. Returns tuple of symbols and coordinates."""
     xyz_file = numpy.genfromtxt(fname=filename, skip_header=2, dtype='unicode')
     symbols = xyz_file[:,0]
     coord = (xyz_file[:,1:])
     coord = coord.astype(numpy.float)
     return symbols, coord

def print_bonds(atom_symbols, atom_coordinates):
    """
    Prints atom symbols and bond length for a set of atoms.
    """
    num_atoms = len(atom_symbols)
    for num1 in range(0, num_atoms):
        for num2 in range(0, num_atoms):
            if num1 < num2:
                bond_length_12 = calculate_distance(atom_coordinates[num1], atom_coordinates[num2])
                if bond_check(bond_length_12) is True:
                    print(F'{atom_symbols[num1]} to {atom_symbols[num2]} : {bond_length_12:.3f}')
# Out:
#   File "<tokenize>", line 23
#     """
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
water_file_location = os.path.join('data', 'water.xyz')
water_symbols, water_coords = open_xyz(water_file_location)

benzene_file_location = os.path.join('data', 'benzene.xyz')
benzene_symbols, benzene_coords = open_xyz(benzene_file_location)

print(F'Printing bonds for water.')
print_bonds(water_symbols, water_coords)

print(F'Printing bonds for benzene.')
print_bonds(benzene_symbols, benzene_coords)
# Out:
# Printing bonds for water.
# O to H1 : 0.969
# O to H2 : 0.969
# Printing bonds for benzene.
# C to H : 1.088
# C to C : 1.403
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/3928636847.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   coord = coord.astype(numpy.float)

# %%
cd ../
# Out:
# /Users/junbao/Desktop/cms-workshop

# %%
pwd
# Out:
# '/Users/junbao/Desktop/cms-workshop'

# %%
water_file_location = os.path.join('data', 'water.xyz')
water_symbols, water_coords = open_xyz(water_file_location)

benzene_file_location = os.path.join('data', 'benzene.xyz')
benzene_symbols, benzene_coords = open_xyz(benzene_file_location)

print(F'Printing bonds for water.')
print_bonds(water_symbols, water_coords)

print(F'Printing bonds for benzene.')
print_bonds(benzene_symbols, benzene_coords)
# Out:
# Printing bonds for water.
# O to H1 : 0.969
# O to H2 : 0.969
# Printing bonds for benzene.
# C to H : 1.088
# C to C : 1.403
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# C to C : 1.403
# C to H : 1.088
# /var/folders/1m/_9p06w2n4fxd0zs4j24_qvzc0000gp/T/ipykernel_96288/3928636847.py:29: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   coord = coord.astype(numpy.float)
